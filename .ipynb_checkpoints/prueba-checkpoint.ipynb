# %%
import tensorflow as tf
#from tensorflow import keras
#from tensorflow.keras import layers
import time

# Verificar que la GPU está disponible y configurada
if tf.test.gpu_device_name():
    print('GPU encontrada')
else:
    print("No se encontró ninguna GPU")

# Crear un modelo de ejemplo
modelo = tf.keras.Sequential([
    tf.keras.layers.Dense(10, input_shape=(784,)),
    tf.keras.layers.Dense(10)
])

# Compilar el modelo
modelo.compile(optimizer='adam', loss='mse')

# Cargar los datos de ejemplo
(x_entrenamiento, y_entrenamiento), (x_prueba, y_prueba) = tf.keras.datasets.mnist.load_data()

# Preprocesar los datos
x_entrenamiento = x_entrenamiento.reshape(60000, 784).astype('float32') / 255.0
x_prueba = x_prueba.reshape(10000, 784).astype('float32') / 255.0

# Entrenar el modelo en la GPU
with tf.device('/device:GPU:0'):
    inicio = time.time()
    modelo.fit(x_entrenamiento, y_entrenamiento, epochs=100, batch_size=32)
    fin = time.time()

# Evaluar el modelo en la GPU
with tf.device('/device:GPU:0'):
    inicio_evaluacion = time.time()
    #loss, accuracy = modelo.evaluate(x_prueba, y_prueba)
    loss = modelo.evaluate (x_prueba, y_prueba, verbose=0)
    fin_evaluacion = time.time()

print(f'Tiempo de entrenamiento: {fin - inicio} segundos')
print(f'Tiempo de evaluación: {fin_evaluacion - inicio_evaluacion} segundos')
#print(f'Pérdida: {loss}, Precisión: {accuracy}')
print(f'Pérdida: {loss}')
# Out:
# No se encontró ninguna GPU
# Epoch 1/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 4.2857
# Epoch 2/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 3.3763
# Epoch 3/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 3.3174
# Epoch 4/100
# 1875/1875 [==============================] - 3s 2ms/step - loss: 3.3051
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2970
# Epoch 6/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2879
# Epoch 7/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2816
# Epoch 8/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2775
# Epoch 9/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2759
# Epoch 10/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2732
# Epoch 11/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.2662
# ...
